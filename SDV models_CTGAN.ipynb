# %% [markdown]
# # CTGAN

# %%
import os
import mlflow

os.environ["MLFLOW_TRACKING_URI"] = "http://localhost:6001"
os.environ["MLFLOW_TRACKING_USERNAME"] = "mlflowadmin"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "mlflowadminpass"
os.environ["MLFLOW_S3_ENDPOINT_URL"] = "http://localhost:9000"
os.environ["AWS_ACCESS_KEY_ID"] = "minioadmin"
os.environ["AWS_SECRET_ACCESS_KEY"] = "minioadmin123!"
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"
os.environ["MLFLOW_S3_IGNORE_TLS"] = "true"   # only if MinIO runs over HTTP

# Point MLflow at the dockerised tracking server (falls back to localhost if env var is missing).
tracking_uri = os.getenv("MLFLOW_TRACKING_URI", "http://localhost:6001")
mlflow.set_tracking_uri(tracking_uri)
mlflow.set_experiment("FORGE - Synthetic Data Evaluation")
# Out:
# <Experiment: artifact_location='s3://mlflow/3', creation_time=1763400434596, experiment_id='3', last_update_time=1763400434596, lifecycle_stage='active', name='FORGE - Synthetic Data Evaluation', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
'''Importing data and removing unnecessary columns'''

import pandas as pd, numpy as np, warnings
warnings.filterwarnings('ignore')

# MLflow setup
import mlflow
import mlflow.sklearn
import os

# MLflow configuration - Choose one option:

# Option 1: Use local file-based backend (no server needed - recommended for development)
mlflow.set_tracking_uri("file:./mlruns")  # Stores runs in local ./mlruns directory

# Option 2: Use MLflow server (uncomment and configure if using server)
# mlflow.set_tracking_uri("http://localhost:6001")
# If your server requires authentication, set these environment variables:
# os.environ['MLFLOW_TRACKING_USERNAME'] = 'your_username'
# os.environ['MLFLOW_TRACKING_PASSWORD'] = 'your_password'
# Or use: mlflow.set_tracking_uri("http://username:password@localhost:6001")

mlflow.set_experiment("Synthetic_Data_Evaluation_CTGAN")

cancer_data = pd.read_csv('data.csv')

cancer_data.drop(['id', 'Unnamed: 32'], axis=1, inplace = True)
cancer_data.replace({'diagnosis':{'M':1, 'B':0}}, inplace=True)
# Out:
# <Experiment: artifact_location=('file:///c:/Users/Gopi.Battineni/OneDrive - University of '
#  'Limerick/Desktop/FORGE/Synthetic_Data_Evaluation-/mlruns/885333851212996048'), creation_time=1763397208495, experiment_id='885333851212996048', last_update_time=1763397208495, lifecycle_stage='active', name='Synthetic_Data_Evaluation_CTGAN', tags={}>

# %%
# End any existing MLflow run before starting a new one
# This prevents errors when re-running cells
try:
    active_run = mlflow.active_run()
    if active_run:
        mlflow.end_run()
        print("Ended existing MLflow run")
except:
    pass

# Display MLflow tracking info
print(f"MLflow tracking URI: {mlflow.get_tracking_uri()}")
print(f"MLflow experiment: {mlflow.get_experiment_by_name('Synthetic_Data_Evaluation_CTGAN').name if mlflow.get_experiment_by_name('Synthetic_Data_Evaluation_CTGAN') else 'Not found'}")
print(f"Runs directory: {os.path.abspath('./mlruns')}")
print("\nTo view runs, start MLflow UI with: mlflow ui")
print("Then open: http://localhost:5000\n")
# Out:
# Ended existing MLflow run
# MLflow tracking URI: file:./mlruns
# MLflow experiment: Synthetic_Data_Evaluation_CTGAN
# Runs directory: c:\Users\Gopi.Battineni\OneDrive - University of Limerick\Desktop\FORGE\Synthetic_Data_Evaluation-\mlruns
#
# To view runs, start MLflow UI with: mlflow ui
# Then open: http://localhost:5000

# %%
cancer_data = pd.read_csv('data.csv')

cancer_data.drop(['id', 'Unnamed: 32'], axis=1, inplace = True)
cancer_data.replace({'diagnosis':{'M':1, 'B':0}}, inplace=True)

# %% [markdown]
# ##### Here I am evaluting different Fidility metrics
#
# Global Fidelity: KS, JS, Wasserstein

# %%
# import sdv (synthetic data valut) and generating meta data

import sdv
from sdv.metadata import SingleTableMetadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(cancer_data)

# %%
# Start MLflow run
mlflow.start_run(run_name="CTGAN_Breast_Cancer")

# single table CTGAN model
from sdv.single_table import CTGANSynthesizer
ctgan = CTGANSynthesizer(metadata=metadata)

# Log model parameters
mlflow.log_param("model_type", "CTGAN")
mlflow.log_param("dataset", "Breast_Cancer_Wisconsin")
mlflow.log_param("num_samples", 1000)
mlflow.log_param("num_features", len(cancer_data.columns))
mlflow.log_param("num_rows_real", len(cancer_data))

ctgan.fit(cancer_data)
synthetic_data_ctgan = ctgan.sample(1000)

# Save model
model_path = "ctgan_model"
ctgan.save(model_path)
mlflow.log_artifacts(model_path, "ctgan_model")

# %%
''' CTGAN stands for Conditional Tabular Generative Adversarial Network    
It’s a special kind of GAN (Generative Adversarial Network) designed for 
abular data — data with columns that can be continuous, categorical, or both.'''

# single table CTGAN model

from sdv.single_table import CTGANSynthesizer
ctgan = CTGANSynthesizer(metadata=metadata)
ctgan.fit(cancer_data)
synthetic_data_ctgan = ctgan.sample(1000)

# %%
# diagnostic and quality check

from sdv.evaluation.single_table import evaluate_quality, run_diagnostic

diagnostic_report = run_diagnostic(cancer_data, synthetic_data_ctgan, metadata)
qulaity_report = evaluate_quality(cancer_data,synthetic_data_ctgan, metadata)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 31/31 [00:00<00:00, 970.78it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 121.26it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 31/31 [00:00<00:00, 205.66it/s]|
# Column Shapes Score: 70.09%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 465/465 [00:03<00:00, 120.40it/s]|
# Column Pair Trends Score: 79.2%
#
# Overall Score (Average): 74.65%

# %% [markdown]
# ## Kolmogrov-simrov (KS) test (Max CDF difference between real/synthetic)

# %%
from sdv.evaluation.single_table import QualityReport

# 1. Initialize report
quality_report = QualityReport()

# 2. Generate with metadata converted to dict
quality_report.generate(
    real_data=cancer_data,
    synthetic_data=synthetic_data_ctgan,
    metadata=metadata.to_dict()  
)

# 3. Get details
details = quality_report.get_details('Column Shapes')
print(details)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 31/31 [00:00<00:00, 256.98it/s]|
# Column Shapes Score: 70.09%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 465/465 [00:03<00:00, 137.80it/s]|
# Column Pair Trends Score: 79.2%
#
# Overall Score (Average): 74.65%
#
#                      Column        Metric     Score
# 0                 diagnosis  TVComplement  0.889583
# 1               radius_mean  KSComplement  0.781315
# 2              texture_mean  KSComplement  0.726497
# 3            perimeter_mean  KSComplement  0.564285
# 4                 area_mean  KSComplement  0.720308
# 5           smoothness_mean  KSComplement  0.534564
# 6          compactness_mean  KSComplement  0.626666
# 7            concavity_mean  KSComplement  0.825420
# 8       concave points_mean  KSComplement  0.542049
# 9             symmetry_mean  KSComplement  0.475866
# 10   fractal_dimension_mean  KSComplement  0.729803
# 11                radius_se  KSComplement  0.837026
# 12               texture_se  KSComplement  0.840504
# 13             perimeter_se  KSComplement  0.749360
# 14                  area_se  KSComplement  0.517053
# 15            smoothness_se  KSComplement  0.504561
# 16           compactness_se  KSComplement  0.847750
# 17             concavity_se  KSComplement  0.905053
# 18        concave points_se  KSComplement  0.657541
# 19              symmetry_se  KSComplement  0.727613
# 20     fractal_dimension_se  KSComplement  0.565292
# 21             radius_worst  KSComplement  0.578221
# 22            texture_worst  KSComplement  0.767859
# 23          perimeter_worst  KSComplement  0.673445
# 24               area_worst  KSComplement  0.819083
# 25         smoothness_worst  KSComplement  0.514411
# 26        compactness_worst  KSComplement  0.622341
# 27          concavity_worst  KSComplement  0.916265
# 28     concave points_worst  KSComplement  0.829717
# 29           symmetry_worst  KSComplement  0.651534
# 30  fractal_dimension_worst  KSComplement  0.786979

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.barplot(
    x='Column', y='Score',
    data=details.sort_values('Score', ascending=False),
    palette='viridis'
)
plt.title('Column Shapes Similarity (KS Complement)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Jensenshannon Distance (Distribution similarity measure)

# %%
from pandas.api.types import is_numeric_dtype
from scipy.spatial.distance import jensenshannon
from sklearn.preprocessing import MinMaxScaler

def _prob_vectors_numeric(real, synth, bins=30, eps=1e-12):
    """Convert numeric columns into comparable probability vectors."""
    real = pd.to_numeric(real, errors='coerce').dropna().to_numpy()
    synth = pd.to_numeric(synth, errors='coerce').dropna().to_numpy()

    edges = np.histogram_bin_edges(np.concatenate([real, synth]), bins=bins)
    r_hist, _ = np.histogram(real, bins=edges)
    s_hist, _ = np.histogram(synth, bins=edges)

    r = r_hist.astype(float) + eps
    s = s_hist.astype(float) + eps
    r /= r.sum()
    s /= s.sum()
    return r, s

def _prob_vectors_categorical(real, synth, eps=1e-12):
    """Convert categorical columns into comparable probability vectors."""
    r_counts = real.astype(str).value_counts(dropna=False)
    s_counts = synth.astype(str).value_counts(dropna=False)
    keys = r_counts.index.union(s_counts.index)
    r = r_counts.reindex(keys, fill_value=0).to_numpy(dtype=float) + eps
    s = s_counts.reindex(keys, fill_value=0).to_numpy(dtype=float) + eps
    r /= r.sum()
    s /= s.sum()
    return r, s, keys

# %%
# ---------- Main function ----------
def compute_js_divergence(real_df: pd.DataFrame,
                          synth_df: pd.DataFrame,
                          bins=30,
                          normalize=True) -> pd.DataFrame:
    """
    Compute Jensen–Shannon Divergence for each column between real and synthetic data.
    Returns a DataFrame with per-feature JS divergence values.
    """

    common_cols = [c for c in real_df.columns if c in synth_df.columns]
    real = real_df[common_cols].copy()
    synth = synth_df[common_cols].copy()

    # Optional normalization for numeric columns
    if normalize:
        num_cols = [c for c in common_cols if is_numeric_dtype(real[c])]
        scaler = MinMaxScaler()
        real[num_cols] = scaler.fit_transform(real[num_cols])
        synth[num_cols] = scaler.transform(synth[num_cols])

    results = []
    for col in common_cols:
        r_col, s_col = real[col], synth[col]

        if is_numeric_dtype(r_col):
            p, q = _prob_vectors_numeric(r_col, s_col, bins=bins)
        else:
            p, q, _ = _prob_vectors_categorical(r_col, s_col)

        # Jensen-Shannon divergence (base=2 → bounded [0,1])
        js_div = jensenshannon(p, q, base=2) ** 2

        results.append({"Feature": col, "JS_Divergence": js_div})

    return pd.DataFrame(results).sort_values("JS_Divergence")

# %%
results = compute_js_divergence(cancer_data, synthetic_data_ctgan, bins="fd", normalize=True)
print(results)

# Log JS Divergence metrics
mlflow.log_metric("js_divergence_mean", results['JS_Divergence'].mean())
mlflow.log_metric("js_divergence_median", results['JS_Divergence'].median())
mlflow.log_metric("js_divergence_max", results['JS_Divergence'].max())
mlflow.log_metric("js_divergence_min", results['JS_Divergence'].min())

# Log JS divergence per feature as metrics
for idx, row in results.iterrows():
    mlflow.log_metric(f"js_divergence_{row['Feature']}", row['JS_Divergence'])
# Out:
#                     Feature  JS_Divergence
# 0                 diagnosis       0.009002
# 27          concavity_worst       0.024742
# 17             concavity_se       0.047918
# 12               texture_se       0.050970
# 7            concavity_mean       0.053083
# 28     concave points_worst       0.053638
# 16           compactness_se       0.061817
# 22            texture_worst       0.069333
# 11                radius_se       0.071650
# 1               radius_mean       0.072942
# 30  fractal_dimension_worst       0.075657
# 24               area_worst       0.079664
# 19              symmetry_se       0.085388
# 10   fractal_dimension_mean       0.087194
# 13             perimeter_se       0.091178
# 2              texture_mean       0.105043
# 4                 area_mean       0.112334
# 29           symmetry_worst       0.117690
# 23          perimeter_worst       0.137139
# 18        concave points_se       0.145175
# 26        compactness_worst       0.150470
# 6          compactness_mean       0.184257
# 3            perimeter_mean       0.189345
# 8       concave points_mean       0.207722
# 21             radius_worst       0.207729
# 20     fractal_dimension_se       0.211784
# 5           smoothness_mean       0.226424
# 15            smoothness_se       0.235021
# 9             symmetry_mean       0.248623
# 25         smoothness_worst       0.259920
# 14                  area_se       0.267231

# %%
# Distributional similarity metrics
''' MMD — Maximum Mean Discrepancy (statistical distance that measures 
the difference between the distributions of two datasets)'''

from sklearn.preprocessing import StandardScaler    
from scipy.stats import wasserstein_distance

scaler = StandardScaler()
real_scaled = scaler.fit_transform(cancer_data.drop(columns=['diagnosis']))
synthetic_scaled = scaler.transform(synthetic_data_ctgan.drop(columns=['diagnosis']))

# MMD (using Gaussian kernel)
def gaussian_kernel(x, y, sigma=1.0):
    x_size = x.shape[0]
    y_size = y.shape[0]
    dim = x.shape[1]
    x_tile = np.tile(x, (y_size, 1))
    y_tile = np.repeat(y, x_size, axis=0)
    return np.exp(-np.sum((x_tile - y_tile)**2, axis=1) / (2 * dim * sigma**2)).reshape(y_size, x_size)

def compute_mmd(x, y, sigma=1.0):
    k_xx = np.mean(gaussian_kernel(x, x, sigma))
    k_yy = np.mean(gaussian_kernel(y, y, sigma))
    k_xy = np.mean(gaussian_kernel(x, y, sigma))
    return k_xx + k_yy - 2 * k_xy

mmd_score = compute_mmd(real_scaled, synthetic_scaled)

print(f"MMD score: {mmd_score:.4f}")

# Log MMD score
mlflow.log_metric("mmd_score", mmd_score)
# Out:
# MMD score: 0.2176

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute JS divergence
results = compute_js_divergence(cancer_data, synthetic_data_ctgan, bins="fd", normalize=True)

# Sort for better readability
results = results.sort_values("JS_Divergence", ascending=False)

# Create bar chart
plt.figure(figsize=(12,6))
bars = sns.barplot(x="Feature", y="JS_Divergence", data=results, palette="viridis")

# Add value labels on each bar
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2, 
        yval + 0.005,                    # vertical offset
        f"{yval:.3f}",                   # formatted value
        ha="center", va="bottom", fontsize=8, rotation=90
    )

# Aesthetics
plt.xticks(rotation=90)
plt.ylabel("JS Divergence (base 2)")
plt.title("Jensen–Shannon Divergence per Feature (CTGAN)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Wasserstein Distance (Distance between full distributions)

# %%
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import wasserstein_distance
import pandas as pd

# Assume cancer_data (real) and synthetic_data (synthetic) are your DataFrames

# Initialize MinMax scaler
scaler = MinMaxScaler()


# Fit on the real data and transform both
real_scaled = pd.DataFrame(scaler.fit_transform(cancer_data), columns=cancer_data.columns)
synthetic_scaled = pd.DataFrame(scaler.transform(synthetic_data_ctgan), columns=synthetic_data_ctgan.columns)

# Compute normalized Wasserstein distance
wasserstein_distances = {}
for col in cancer_data.columns:
    dist = wasserstein_distance(real_scaled[col], synthetic_scaled[col])
    wasserstein_distances[col] = dist
    print(f"{col}: {dist:.4f}")

# Log Wasserstein distances
mlflow.log_metric("wasserstein_distance_mean", np.mean(list(wasserstein_distances.values())))
mlflow.log_metric("wasserstein_distance_median", np.median(list(wasserstein_distances.values())))
mlflow.log_metric("wasserstein_distance_max", np.max(list(wasserstein_distances.values())))
mlflow.log_metric("wasserstein_distance_min", np.min(list(wasserstein_distances.values())))

# Log per-feature Wasserstein distances
for col, dist in wasserstein_distances.items():
    mlflow.log_metric(f"wasserstein_{col}", dist)
# Out:
# diagnosis: 0.1104
# radius_mean: 0.0848
# texture_mean: 0.0967
# perimeter_mean: 0.1947
# area_mean: 0.0703
# smoothness_mean: 0.1666
# compactness_mean: 0.1626
# concavity_mean: 0.0533
# concave points_mean: 0.1426
# symmetry_mean: 0.1770
# fractal_dimension_mean: 0.1090
# radius_se: 0.0151
# texture_se: 0.0329
# perimeter_se: 0.0257
# area_se: 0.0433
# smoothness_se: 0.0971
# compactness_se: 0.0377
# concavity_se: 0.0113
# concave points_se: 0.0759
# symmetry_se: 0.0669
# fractal_dimension_se: 0.0709
# radius_worst: 0.1676
# texture_worst: 0.1037
# perimeter_worst: 0.0932
# area_worst: 0.0279
# smoothness_worst: 0.1915
# compactness_worst: 0.1461
# concavity_worst: 0.0160
# concave points_worst: 0.0677
# symmetry_worst: 0.0931
# fractal_dimension_worst: 0.0688

# %%
import gower 

# remove the target variable for gower distance calculation

X_real = cancer_data.drop('diagnosis', axis=1)
X_synth = synthetic_data_ctgan.drop('diagnosis', axis=1) 

# compute gower distance

gower_real = 1 - gower.gower_matrix(X_real)
gower_synth = 1 - gower.gower_matrix(X_synth)
gower_combined = 1 - gower.gower_matrix(pd.concat([X_real, X_synth], axis=0))

# upper triangle indices

real_upper = gower_real[np.triu_indices_from(gower_real, k=1)]
synth_upper = gower_synth[np.triu_indices_from(gower_synth, k=1)]

# Max and average intra-set similarity

max_intra_real = np.max(real_upper)
avg_intra_real = np.mean(real_upper)

max_intra_synth = np.max(synth_upper)
avg_intra_synth = np.mean(synth_upper)

# Flatten the cross-set matrix
cross_flat = gower_combined.flatten()

max_cross = np.max(cross_flat)
avg_cross = np.mean(cross_flat)
print("Intra-set Similarity (Real):")
print(f"Max = {max_intra_real:.4f}, Avg = {avg_intra_real:.4f}\n")

print("Intra-set Similarity (Synthetic):")
print(f"Max = {max_intra_synth:.4f}, Avg = {avg_intra_synth:.4f}\n")

print("Cross-set Similarity (Real vs Synthetic):")
print(f"Max = {max_cross:.4f}, Avg = {avg_cross:.4f}")

# Log Gower distance metrics
mlflow.log_metric("gower_max_intra_real", max_intra_real)
mlflow.log_metric("gower_avg_intra_real", avg_intra_real)
mlflow.log_metric("gower_max_intra_synth", max_intra_synth)
mlflow.log_metric("gower_avg_intra_synth", avg_intra_synth)
mlflow.log_metric("gower_max_cross", max_cross)
mlflow.log_metric("gower_avg_cross", avg_cross)
# Out:
# Intra-set Similarity (Real):
# Max = 0.9809, Avg = 0.8528
#
# Intra-set Similarity (Synthetic):
# Max = 0.9202, Avg = 0.8099
#
# Cross-set Similarity (Real vs Synthetic):
# Max = 1.0000, Avg = 0.8266

# %% [markdown]
# ### t-SNE = Local Fidelity / Distribution Visualization Metric

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, random_state=42)
combined = np.vstack([real_scaled, synthetic_scaled])
tsne_result = tsne.fit_transform(combined)
labels = ['Real'] * len(real_scaled) + ['Synthetic'] * len(synthetic_scaled)

plt.figure(figsize=(6,5))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1],
            c=['blue' if l == 'Real' else 'orange' for l in labels],
            alpha=0.6, label=None)
plt.title("t-SNE: Real vs Synthetic Data Overlap")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.show()

# %% [markdown]
# ### Cosine Similarity Metrics

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Cosine similarity
cross_sim = cosine_similarity(real_scaled, synthetic_scaled)
avg_sim = np.mean(cross_sim)
max_sim = np.max(cross_sim)


print(f"\n ----- Sample-Level Similarity--------- \n")

print(f"Average cosine similarity: {avg_sim:.4f}")
print(f"Maximum cosine similarity: {max_sim:.4f}")

# Log cosine similarity metrics
mlflow.log_metric("cosine_similarity_avg", avg_sim)
mlflow.log_metric("cosine_similarity_max", max_sim)
# Out:
#  ----- Sample-Level Similarity---------
#
# Average cosine similarity: 0.7393
# Maximum cosine similarity: 0.9531

# %% [markdown]
# # Utility

# %%
# TSTR (Train on synthetic and test on real data)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# Define real and synthetic datasets
real_data = cancer_data
synthetic_data = synthetic_data_ctgan

# -----------------------------
# 1. Train on Synthetic → Test on Real (TSTR)
# -----------------------------

# Split synthetic data (train/test)
X_synth = synthetic_data.drop(['diagnosis'], axis=1)
y_synth = synthetic_data['diagnosis']
X_train_synth, X_test_synth, y_train_synth, y_test_synth = train_test_split(
    X_synth, y_synth, test_size=0.2, random_state=42
)

# Split real data (train/test)
X_real = real_data.drop(['diagnosis'], axis=1)
y_real = real_data['diagnosis']
X_train_real, X_test_real, y_train_real, y_test_real = train_test_split(
    X_real, y_real, test_size=0.2, random_state=42
)

# Scale features using scaler fitted on synthetic training data
scaler = StandardScaler().fit(X_train_synth)
X_train_synth_scaled = scaler.transform(X_train_synth)
X_test_real_scaled = scaler.transform(X_test_real)

# Train model on synthetic data
model_tstr = RandomForestClassifier(random_state=42)
model_tstr.fit(X_train_synth_scaled, y_train_synth)

# Test on real data
y_pred_real = model_tstr.predict(X_test_real_scaled)
y_pred_prob_real = model_tstr.predict_proba(X_test_real_scaled)[:, 1]

# Evaluate TSTR performance
acc_tstr = accuracy_score(y_test_real, y_pred_real)
f1_tstr = f1_score(y_test_real, y_pred_real)
auc_tstr = roc_auc_score(y_test_real, y_pred_prob_real)

print("Train on Synthetic, Test on Real (TSTR):")
print(f"Accuracy = {acc_tstr:.3f}")
print(f"F1 Score = {f1_tstr:.3f}")
print(f"AUC = {auc_tstr:.3f}")


# -----------------------------
# 2. Baseline: Train Real → Test Real (TRTR)
# -----------------------------

# Scale real data using scaler fitted on real training set
scaler_real = StandardScaler().fit(X_train_real)
X_train_real_scaled = scaler_real.transform(X_train_real)
X_test_real_scaled_baseline = scaler_real.transform(X_test_real)

# Train on real data
model_baseline = RandomForestClassifier(random_state=42)
model_baseline.fit(X_train_real_scaled, y_train_real)

# Test on real data
y_pred_baseline = model_baseline.predict(X_test_real_scaled_baseline)
y_pred_prob_baseline = model_baseline.predict_proba(X_test_real_scaled_baseline)[:, 1]

# Evaluate baseline model
acc_trtr = accuracy_score(y_test_real, y_pred_baseline)
f1_trtr = f1_score(y_test_real, y_pred_baseline)
auc_trtr = roc_auc_score(y_test_real, y_pred_prob_baseline)

print("\nBaseline: Train on Real, Test on Real (TRTR):")
print(f"Accuracy = {acc_trtr:.3f}")
print(f"F1 Score = {f1_trtr:.3f}")
print(f"AUC = {auc_trtr:.3f}")

# Log utility metrics
mlflow.log_metric("tstr_accuracy", acc_tstr)
mlflow.log_metric("tstr_f1_score", f1_tstr)
mlflow.log_metric("tstr_auc", auc_tstr)
mlflow.log_metric("trtr_accuracy", acc_trtr)
mlflow.log_metric("trtr_f1_score", f1_trtr)
mlflow.log_metric("trtr_auc", auc_trtr)
# Out:
# Train on Synthetic, Test on Real (TSTR):
# Accuracy = 0.588
# F1 Score = 0.647
# AUC = 0.895
#
# Baseline: Train on Real, Test on Real (TRTR):
# Accuracy = 0.965
# F1 Score = 0.952
# AUC = 0.995

# %% [markdown]
# # Privacy

# %%
# Privacy (Nearest Neighbor Distance)

from sklearn.neighbors import NearestNeighbors


# Compute Nearest Neighbor Distance
nn = NearestNeighbors(n_neighbors=1).fit(real_scaled)
distances, _ = nn.kneighbors(synthetic_scaled)
avg_nn_dist = np.mean(distances)

print("Privacy Check:")
print(f"Average Nearest Neighbor Distance (Synthetic → Real): {avg_nn_dist:.4f}")

# Log privacy metrics
mlflow.log_metric("privacy_avg_nn_distance", avg_nn_dist)
# Out:
# Privacy Check:
# Average Nearest Neighbor Distance (Synthetic → Real): 0.9918

# %% [markdown]
# # Bivariate analysis

# %%
from itertools import combinations
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.preprocessing import MinMaxScaler

real_df = cancer_data
synth_df = synthetic_data_ctgan

# Make sure column order matches
synth_df = synth_df[real_df.columns]

def bivariate_quality_cancer(real_df, synth_df, target='diagnosis'):
    # Identify numeric and target columns
    num_cols = [c for c in real_df.columns if c != target]
    
    # ----- Min-Max scaling on numeric columns -----
    scaler = MinMaxScaler()
    
    real_scaled = real_df.copy()
    synth_scaled = synth_df.copy()
    
    # Fit on real, transform both real and synthetic
    real_scaled[num_cols] = scaler.fit_transform(real_df[num_cols])
    synth_scaled[num_cols] = scaler.transform(synth_df[num_cols])
    
    results_corr = []
    results_target = []

    # ===== 1) Numeric-to-numeric: Δ-correlation =====
    for a, b in combinations(num_cols, 2):
        r_corr = real_scaled[[a, b]].corr().iloc[0, 1]
        s_corr = synth_scaled[[a, b]].corr().iloc[0, 1]
        results_corr.append({
            'var_a': a,
            'var_b': b,
            'delta_corr': abs(r_corr - s_corr)
        })
    
    # ===== 2) Numeric-to-target: Δ-Wasserstein between classes =====
    for col in num_cols:
        # Split by target for real and synthetic
        r_groups = [g[col].values for _, g in real_scaled.groupby(target)]
        s_groups = [g[col].values for _, g in synth_scaled.groupby(target)]
        
        # Only proceed if exactly 2 classes (benign/malignant)
        if len(r_groups) == 2 and len(s_groups) == 2:
            d_real = stats.wasserstein_distance(*r_groups)
            d_synth = stats.wasserstein_distance(*s_groups)
            results_target.append({
                "feature": col,
                "delta_wasserstein": abs(d_real - d_synth)
            })

    corr_df = pd.DataFrame(results_corr).sort_values("delta_corr", ascending=False)
    target_df = pd.DataFrame(results_target).sort_values("delta_wasserstein", ascending=False)
    
    return corr_df, target_df

# Run the analysis
corr_results, target_results = bivariate_quality_cancer(real_df=cancer_data, 
                                                        synth_df=synthetic_data_ctgan)

# Largest differences in pairwise correlations
print(corr_results.head(10))

print('================================')

# Features that differ most by diagnosis class
print(target_results.head(10))

# Log bivariate analysis metrics
mlflow.log_metric("bivariate_max_delta_corr", corr_results['delta_corr'].max())
mlflow.log_metric("bivariate_mean_delta_corr", corr_results['delta_corr'].mean())
mlflow.log_metric("bivariate_max_delta_wasserstein", target_results['delta_wasserstein'].max())
mlflow.log_metric("bivariate_mean_delta_wasserstein", target_results['delta_wasserstein'].mean())
# Out:
#               var_a                var_b  delta_corr
# 246       radius_se         perimeter_se    1.044244
# 77   perimeter_mean           area_worst    1.036841
# 74   perimeter_mean         radius_worst    1.013750
# 103       area_mean           area_worst    1.004832
# 159  concavity_mean  concave points_mean    1.003122
# 391    radius_worst      perimeter_worst    1.001364
# 19      radius_mean         radius_worst    1.000777
# 247       radius_se              area_se    1.000646
# 76   perimeter_mean      perimeter_worst    0.985211
# 392    radius_worst           area_worst    0.983360
# ================================
#                  feature  delta_wasserstein
# 27  concave points_worst           0.308333
# 7    concave points_mean           0.298172
# 6         concavity_mean           0.235813
# 2         perimeter_mean           0.233516
# 20          radius_worst           0.229639
# 3              area_mean           0.188228
# 26       concavity_worst           0.185472
# 0            radius_mean           0.180873
# 5       compactness_mean           0.179197
# 23            area_worst           0.175383

# %%
# Compare correlations side by side

# Plotting both correlation metrics as heatmaps 

import matplotlib.pyplot as plt
import seaborn as sns

num_cols = [c for c in real_df.columns if c != "diagnosis"]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(real_df[num_cols].corr(), cmap="coolwarm", center=0, ax=axes[0])
axes[0].set_title("Real Data Correlation Matrix")

sns.heatmap(synth_df[num_cols].corr(), cmap="coolwarm", center=0, ax=axes[1])
axes[1].set_title("Synthetic Data Correlation Matrix")

plt.tight_layout()
plt.show()

# %%
diff_corr = abs(real_df[num_cols].corr() - synth_df[num_cols].corr())
plt.figure(figsize=(8,6))
sns.heatmap(diff_corr, cmap="Reds", center=0)
plt.title("Absolute Correlation Difference |Δρ|")
plt.show()

# %%
# Overlay 2D scatter (bivariate plot) for selected pair

x = "radius_mean"
y = "texture_mean"

plt.figure(figsize=(7,6))
plt.scatter(real_df[x], real_df[y], alpha=0.5, label="Real", color="blue")
plt.scatter(synth_df[x], synth_df[y], alpha=0.5, label="Synthetic", color="orange")
plt.xlabel(x)
plt.ylabel(y)
plt.legend()
plt.title(f"{x} vs {y}: Real vs Synthetic")
plt.show()

# %%
# Compare conditional distributions (numeric ↔ categorical)

import seaborn as sns

feature = "area_mean"

plt.figure(figsize=(8,6))
sns.kdeplot(data=real_df, x=feature, hue="diagnosis", fill=True, alpha=0.4, label="Real")
sns.kdeplot(data=synth_df, x=feature, hue="diagnosis", fill=True, alpha=0.4, linestyle="--", label="Synthetic")
plt.title(f"{feature} by Diagnosis — Real vs Synthetic")
plt.legend()
plt.show()

# %%
# PCA projection colored by dataset type

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

num_cols = [c for c in real_df.columns if c != "diagnosis"]
scaler = StandardScaler()
X_real = scaler.fit_transform(real_df[num_cols])
X_syn = scaler.transform(synth_df[num_cols])

pca = PCA(n_components=2)
X_all = np.vstack([X_real, X_syn])
pca_all = pca.fit_transform(X_all)

n_real = len(X_real)
labels = np.array(["Real"] * n_real + ["Synthetic"] * len(X_syn))

plt.figure(figsize=(8,6))
plt.scatter(pca_all[labels=="Real",0], pca_all[labels=="Real",1], color="blue", alpha=0.5, label="Real")
plt.scatter(pca_all[labels=="Synthetic",0], pca_all[labels=="Synthetic",1], color="orange", alpha=0.5, label="Synthetic")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.title("PCA Projection — Real vs Synthetic Data")
plt.legend()
plt.show()

# %%
# Quick check: Verify MLflow runs exist
import os
mlruns_path = "./mlruns"
if os.path.exists(mlruns_path):
    print("✓ MLflow runs directory exists")
    # Count experiments
    experiments = [d for d in os.listdir(mlruns_path) if os.path.isdir(os.path.join(mlruns_path, d)) and d.isdigit()]
    print(f"✓ Found {len(experiments)} experiment(s)")
    
    # Count runs in the experiment
    if experiments:
        exp_path = os.path.join(mlruns_path, experiments[0])
        runs = [d for d in os.listdir(exp_path) if os.path.isdir(os.path.join(exp_path, d)) and len(d) == 32]
        print(f"✓ Found {len(runs)} run(s) in experiment")
        
    print(f"\n📁 Runs location: {os.path.abspath(mlruns_path)}")
    print("\n🚀 To view in MLflow UI:")
    print("   1. Open terminal in this directory")
    print("   2. Run: mlflow ui")
    print("   3. Open browser: http://localhost:6001")
else:
    print("⚠ MLflow runs directory not found. Run the notebook cells to create runs.")
# Out:
# ✓ MLflow runs directory exists
# ✓ Found 2 experiment(s)
# ✓ Found 0 run(s) in experiment
#
# 📁 Runs location: c:\Users\Gopi.Battineni\OneDrive - University of Limerick\Desktop\FORGE\Synthetic_Data_Evaluation-\mlruns
#
# 🚀 To view in MLflow UI:
#    1. Open terminal in this directory
#    2. Run: mlflow ui
#    3. Open browser: http://localhost:6001

# %% [markdown]
# # Multi-variate analysis

# %%
# MMD computation (global distribution distance)

from sklearn.metrics.pairwise import rbf_kernel
def mmd_rbf(X, Y, gamma=None):
    if gamma is None:
        Z = np.vstack([X, Y])
        dists = np.sqrt(((Z[:,None,:]-Z[None,:,:])**2).sum(-1))
        med = np.median(dists[dists>0])
        gamma = 1.0 / (2*(med**2))
    Kxx = rbf_kernel(X, X, gamma)
    Kyy = rbf_kernel(Y, Y, gamma)
    Kxy = rbf_kernel(X, Y, gamma)
    n, m = len(X), len(Y)
    return (Kxx.sum() - np.trace(Kxx))/(n*(n-1)) + (Kyy.sum() - np.trace(Kyy))/(m*(m-1)) - 2*Kxy.mean()

mmd_value = mmd_rbf(X_real, X_synth)
print("Global MMD (RBF):", mmd_value)

# Log global MMD
mlflow.log_metric("mmd_rbf_global", mmd_value)
# Out:
# Global MMD (RBF): 0.7884773940770098

# %%
# PCA visualization

import matplotlib.pyplot as plt
pca = PCA(n_components=2)
X_all = np.vstack([X_real, X_synth])
labels = np.array(['Real'] * len(X_real) + ['Synthetic'] * len(X_synth))
X_pca = pca.fit_transform(X_all)

plt.figure(figsize=(8,6))
plt.scatter(X_pca[labels=='Real',0], X_pca[labels=='Real',1], color='blue', alpha=0.5, label='Real')
plt.scatter(X_pca[labels=='Synthetic',0], X_pca[labels=='Synthetic',1], color='orange', alpha=0.5, label='Synthetic')
plt.title("PCA Projection — Real vs Synthetic")
plt.xlabel("PC1"); plt.ylabel("PC2"); plt.legend(); plt.show()

# %%
# Classifier Two-Sample Test

y_real = np.ones(len(X_real))
y_synth = np.zeros(len(X_synth))
X = np.vstack([X_real, X_synth])
y = np.hstack([y_real, y_synth])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
clf = RandomForestClassifier(n_estimators=200, random_state=42)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Two-Sample Classifier Accuracy:", acc)

# Log two-sample test accuracy
mlflow.log_metric("two_sample_classifier_accuracy", acc)

# Save synthetic data as artifact
synthetic_data_ctgan.to_csv("synthetic_data_ctgan.csv", index=False)
mlflow.log_artifact("synthetic_data_ctgan.csv")

# End MLflow run
mlflow.end_run()

print("\nMLflow run completed! Check http://localhost:6001")
# Out:
# Two-Sample Classifier Accuracy: 1.0
#
# MLflow run completed! Check http://localhost:6001
